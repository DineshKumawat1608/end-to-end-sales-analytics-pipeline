# %% [markdown]
# <div style="background-color:#f4f8ff; padding:16px; border-left:6px solid #1f4fd8; border-radius:6px; color:#000;">
#
# <h2 style="margin-top:0; color:#000;">Measures Exploration (Key Metrics)</h2>
#
# <h4 style="color:#000;">Purpose</h4>
# <ul>
#   <li>Calculate aggregated metrics such as totals and averages for quick insights.</li>
#   <li>Identify overall trends and detect potential anomalies.</li>
# </ul>
#
# <h4 style="color:#000;">SQL Functions Used</h4>
# <ul>
#   <li><b>COUNT()</b></li>
#   <li><b>SUM()</b></li>
#   <li><b>AVG()</b></li>
# </ul>
#
# </div>

# %% [markdown]
# <div style="background-color:#f4f8ff; padding:10px; border-left:6px solid #1f4fd8; border-radius:6px; color:#000; font-size:20px;">
# <b>1. Find the Total Sales</b>
# </div>

# %%
query = """
SELECT SUM(sales_amount) AS total_sales FROM gold.fact_sales
"""

df = pd.read_sql(query, engine)
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>total_sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>29356250</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="background-color:#f4f8ff; padding:10px; border-left:6px solid #1f4fd8; border-radius:6px; color:#000; font-size:20px;">
# <strong>2. Find how many items are sold</strong>
# </div>

# %%
query = """
SELECT SUM(quantity) AS total_quantity FROM gold.fact_sales
"""

df = pd.read_sql(query, engine)
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>total_quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>60423</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="background-color:#f4f8ff; padding:10px; border-left:6px solid #1f4fd8; border-radius:6px; color:#000; font-size:20px;">
# <strong>3. Find the average selling price</strong>
# </div>

# %%
query = """
SELECT AVG(price) AS avg_price FROM gold.fact_sales
"""

df = pd.read_sql(query, engine)
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>avg_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>486</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="background-color:#f4f8ff; padding:10px; border-left:6px solid #1f4fd8; border-radius:6px; color:#000; font-size:20px;">
# <strong>4. *************************Find the Total number of Orders</strong>
# </div>

# %%
query = """
SELECT COUNT(DISTINCT order_number) AS total_orders FROM gold.fact_sales
"""

df = pd.read_sql(query, engine)
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>total_orders</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>27659</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="background-color:#f4f8ff; padding:10px; border-left:6px solid #1f4fd8; border-radius:6px; color:#000; font-size:20px;">
# <strong>5. Find the total number of products</strong>
# </div>

# %%
query = """
SELECT COUNT(product_name) AS total_products FROM gold.dim_products
"""

df = pd.read_sql(query, engine)
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>total_products</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>295</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="background-color:#f4f8ff; padding:10px; border-left:6px solid #1f4fd8; border-radius:6px; color:#000; font-size:20px;">
# <strong>6. Find the total number of customers</strong>
# </div>

# %%
query = """
SELECT COUNT(customer_key) AS total_customers FROM gold.dim_customers;
"""

df = pd.read_sql(query, engine)
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>total_customers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>18484</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="background-color:#f4f8ff; padding:10px; border-left:6px solid #1f4fd8; border-radius:6px; color:#000; font-size:20px;">
# <strong>7. Find the total number of customers that has placed an order</strong>
# </div>

# %%
query = """
SELECT COUNT(DISTINCT customer_key) AS total_customers FROM gold.fact_sales;
"""

df = pd.read_sql(query, engine)
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>total_customers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>18484</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="background-color:#f4f8ff; padding:10px; border-left:6px solid #1f4fd8; border-radius:6px; color:#000; font-size:20px;">
# <strong>8. Generate a Report that shows all key metrics of the business</strong>
# </div>

# %%
query = """
SELECT 'Total Sales' AS measure_name, SUM(sales_amount) AS measure_value FROM gold.fact_sales
UNION ALL
SELECT 'Total Quantity', SUM(quantity) FROM gold.fact_sales
UNION ALL
SELECT 'Average Price', AVG(price) FROM gold.fact_sales
UNION ALL
SELECT 'Total Orders', COUNT(DISTINCT order_number) FROM gold.fact_sales
UNION ALL
SELECT 'Total Products', COUNT(DISTINCT product_name) FROM gold.dim_products
UNION ALL
SELECT 'Total Customers', COUNT(customer_key) FROM gold.dim_customers;
"""
df = pd.read_sql(query, engine)
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>measure_name</th>
#       <th>measure_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Total Sales</td>
#       <td>29356250</td>
#     </tr>
#     <tr>
#       <td>Total Quantity</td>
#       <td>60423</td>
#     </tr>
#     <tr>
#       <td>Average Price</td>
#       <td>486</td>
#     </tr>
#     <tr>
#       <td>Total Orders</td>
#       <td>27659</td>
#     </tr>
#     <tr>
#       <td>Total Products</td>
#       <td>295</td>
#     </tr>
#     <tr>
#       <td>Total Customers</td>
#       <td>18484</td>
#     </tr>
#   </tbody>
# </table>
